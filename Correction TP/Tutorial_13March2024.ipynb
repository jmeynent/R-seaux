# %% [markdown]
# # Exercises 13 March 2024: Interlocks

# %% [markdown]
# ## Preparation

# %%
# import networkx (and other useful packages)
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# We use data from:
# Seierstad C. and Opsahl T. 2011. For the few not the many? The effects of affirmative action on presence, prominence, and social capital of female directors in Norway. Scandinavian Journal of Management, 27 (1), 44-54

# %%
## Import data with Pandas
# First set of nodes: Directors
Directors = pd.read_csv('Directors.txt', sep=' ', encoding='latin1') # specified encoding due to Norwegian names
Directors
# Out:
#       Director_ID                    Director_Name  Director_Gender
# 0               1                    Aage Jakobsen                1
# 1               2                 Aage Johan Remøy                1
# 2               3  Aage Rasmus Bjelland Figenschou                1
# 3               4             Aagot Irene Skjeldal                2
# 4               5                   Aase Gundersen                2
# ...           ...                              ...              ...
# 5762         5763             Yuhong Jin Hermansen                2
# 5763         5764                  Yvonne Berntzen                2
# 5764         5765                 Yvonne Skramstad                2
# 5765         5766                        Zhong Bei                2
# 5766         5767                  Zuzana Muranska                2
#
# [5767 rows x 3 columns]

# %%
# Second set of nodes: Companies
Companies = pd.read_csv('Companies.txt', header=None, sep='\t') 
Companies
# Out:
#        0          1                                          2               3
# 0      1  879447992                          24SEVENOFFICE ASA       0667 OSLO
# 1      2  990031479                            A-COM NORGE ASA       0355 OSLO
# 2      3  890687792             ABERDEEN EIENDOMSFOND ASIA ASA       0230 OSLO
# 3      4  989761390  ABERDEEN EIENDOMSFOND NORDEN/BALTIKUM ASA       0255 OSLO
# 4      5  988671258         ABERDEEN EIENDOMSFOND NORGE II ASA       0255 OSLO
# ..   ...        ...                                        ...             ...
# 379  380  882757692                                 WILSON ASA     5003 BERGEN
# 380  381  985224323                      WINTERSHALL NORGE ASA  4008 STAVANGER
# 381  382  987778490                             YA HOLDING ASA       0369 OSLO
# 382  383  986228608                     YARA INTERNATIONAL ASA       0257 OSLO
# 383  384  990874050                               ZONCOLAN ASA       0158 OSLO
#
# [384 rows x 4 columns]

# %%
# rename columns
Companies.rename(columns = {0 :'Company', 1:'Org_nb', 2:'Company_name', 3:'Postcode_City'}, inplace=True)
Companies.head()
# Out:
#    Company     Org_nb                               Company_name Postcode_City
# 0        1  879447992                          24SEVENOFFICE ASA     0667 OSLO
# 1        2  990031479                            A-COM NORGE ASA     0355 OSLO
# 2        3  890687792             ABERDEEN EIENDOMSFOND ASIA ASA     0230 OSLO
# 3        4  989761390  ABERDEEN EIENDOMSFOND NORDEN/BALTIKUM ASA     0255 OSLO
# 4        5  988671258         ABERDEEN EIENDOMSFOND NORGE II ASA     0255 OSLO

# %%
## Now import edges (let's take August 2011)
interlocks8 = pd.read_csv('Directors_boards_2011-08-01.txt', sep=' ', header = None)
interlocks8
# Out:
#         0     1
# 0       1  2149
# 1       1  2910
# 2       1  3684
# 3       1  3754
# 4       2   766
# ...   ...   ...
# 1741  383  3410
# 1742  383  4031
# 1743  384   958
# 1744  384  4233
# 1745  384  4548
#
# [1746 rows x 2 columns]

# %%
# rename columns
interlocks8.rename(columns = {0 :'Company', 1:'Director'}, inplace=True)
interlocks8.head()
# Out:
#    Company  Director
# 0        1      2149
# 1        1      2910
# 2        1      3684
# 3        1      3754
# 4        2       766

# %%
# It turns out that both Directors and Companies are coded with numbers that start at 1
# Rename IDs to avoid confusion
interlocks8['Director'] = 'D' + interlocks8['Director'].astype(str)
interlocks8['Company'] = 'C' + interlocks8['Company'].astype(str)
interlocks8.head()
# Out:
#   Company Director
# 0      C1    D2149
# 1      C1    D2910
# 2      C1    D3684
# 3      C1    D3754
# 4      C2     D766

# %%
# Let's do the same in attribute datasets
Companies['Company'] = 'C' + Companies['Company'].astype(str)
Companies
# Out:
#     Company     Org_nb                               Company_name  \
# 0        C1  879447992                          24SEVENOFFICE ASA
# 1        C2  990031479                            A-COM NORGE ASA
# 2        C3  890687792             ABERDEEN EIENDOMSFOND ASIA ASA
# 3        C4  989761390  ABERDEEN EIENDOMSFOND NORDEN/BALTIKUM ASA
# 4        C5  988671258         ABERDEEN EIENDOMSFOND NORGE II ASA
# ..      ...        ...                                        ...
# 379    C380  882757692                                 WILSON ASA
# 380    C381  985224323                      WINTERSHALL NORGE ASA
# 381    C382  987778490                             YA HOLDING ASA
# 382    C383  986228608                     YARA INTERNATIONAL ASA
# 383    C384  990874050                               ZONCOLAN ASA
#
#       Postcode_City
# 0         0667 OSLO
# 1         0355 OSLO
# 2         0230 OSLO
# 3         0255 OSLO
# 4         0255 OSLO
# ..              ...
# 379     5003 BERGEN
# 380  4008 STAVANGER
# 381       0369 OSLO
# 382       0257 OSLO
# 383       0158 OSLO
#
# [384 rows x 4 columns]

# %%
# Let's do the same in attribute datasets
Directors['Director_ID'] = 'D' + Directors['Director_ID'].astype(str)
Directors
# Out:
#      Director_ID                    Director_Name  Director_Gender
# 0             D1                    Aage Jakobsen                1
# 1             D2                 Aage Johan Remøy                1
# 2             D3  Aage Rasmus Bjelland Figenschou                1
# 3             D4             Aagot Irene Skjeldal                2
# 4             D5                   Aase Gundersen                2
# ...          ...                              ...              ...
# 5762       D5763             Yuhong Jin Hermansen                2
# 5763       D5764                  Yvonne Berntzen                2
# 5764       D5765                 Yvonne Skramstad                2
# 5765       D5766                        Zhong Bei                2
# 5766       D5767                  Zuzana Muranska                2
#
# [5767 rows x 3 columns]

# %% [markdown]
# ## Create graph

# %%
### Create a graph with the August interlocks
interlocks_G = nx.Graph()  # start by generating empty graph

# First add nodes
interlocks_G.add_nodes_from(interlocks8.iloc[:, 0], bipartite=0) # companies
interlocks_G.add_nodes_from(interlocks8.iloc[:, 1], bipartite=1) # persons

print(interlocks_G)
# Out:
# Graph with 1776 nodes and 0 edges

# %%
# now add edges (August interlocks)
interlocks_G.add_edges_from([(Company, Director) for (Company, Director)
              in interlocks8[['Company', 'Director']].to_numpy()])
print((interlocks_G))
# Out:
# Graph with 1776 nodes and 1746 edges

# %%
# Is the graph bipartite?
nx.is_bipartite(interlocks_G)
# Out:
# True

# %%
# check bipartite attribute
nx.get_node_attributes(interlocks_G, "bipartite")
# Out:
# {'C1': 0,
#  'C2': 0,
#  'C3': 0,
#  'C4': 0,
#  'C5': 0,
#  'C6': 0,
#  'C7': 0,
#  'C8': 0,
#  'C10': 0,
#  'C11': 0,
#  'C12': 0,
#  'C13': 0,
#  'C14': 0,
#  'C15': 0,
#  'C16': 0,
#  'C17': 0,
#  'C18': 0,
#  'C19': 0,
#  'C20': 0,
#  'C21': 0,
#  'C22': 0,
#  'C23': 0,
#  'C24': 0,
#  'C25': 0,
#  'C26': 0,
#  'C27': 0,
#  'C28': 0,
#  'C29': 0,
#  'C30': 0,
#  'C31': 0,
#  'C32': 0,
#  'C33': 0,
#  'C34': 0,
#  'C35': 0,
#  'C36': 0,
#  'C37': 0,
#  'C38': 0,
#  'C39': 0,
#  'C40': 0,
#  'C41': 0,
#  'C42': 0,
#  'C43': 0,
#  'C44': 0,
#  'C45': 0,
#  'C47': 0,
#  'C48': 0,
#  'C49': 0,
#  'C51': 0,
#  'C52': 0,
#  'C53': 0,
#  'C54': 0,
#  'C55': 0,
#  'C56': 0,
#  'C57': 0,
#  'C58': 0,
#  'C59': 0,
#  'C60': 0,
#  'C61': 0,
#  'C62': 0,
#  'C63': 0,
#  'C64': 0,
#  'C65': 0,
#  'C66': 0,
#  'C67': 0,
#  'C70': 0,
#  'C71': 0,
#  'C72': 0,
#  'C73': 0,
#  'C74': 0,
#  'C75': 0,
#  'C76': 0,
#  'C77': 0,
#  'C78': 0,
#  'C79': 0,
#  'C80': 0,
#  'C81': 0,
#  'C82': 0,
#  'C83': 0,
#  'C84': 0,
#  'C85': 0,
#  'C86': 0,
#  'C87': 0,
#  'C88': 0,
#  'C89': 0,
#  'C90': 0,
#  'C91': 0,
#  'C92': 0,
#  'C93': 0,
#  'C94': 0,
#  'C95': 0,
#  'C96': 0,
#  'C97': 0,
#  'C98': 0,
#  'C99': 0,
#  'C100': 0,
#  'C101': 0,
#  'C102': 0,
#  'C103': 0,
#  'C104': 0,
#  'C105': 0,
#  'C106': 0,
#  'C107': 0,
#  'C108': 0,
#  'C109': 0,
#  'C110': 0,
#  'C111': 0,
#  'C112': 0,
#  'C113': 0,
#  'C114': 0,
#  'C115': 0,
#  'C117': 0,
#  'C118': 0,
#  'C119': 0,
#  'C120': 0,
#  'C121': 0,
#  'C122': 0,
#  'C125': 0,
#  'C126': 0,
#  'C127': 0,
#  'C128': 0,
#  'C129': 0,
#  'C130': 0,
#  'C131': 0,
#  'C132': 0,
#  'C133': 0,
#  'C134': 0,
#  'C135': 0,
#  'C136': 0,
#  'C137': 0,
#  'C138': 0,
#  'C139': 0,
#  'C140': 0,
#  'C141': 0,
#  'C142': 0,
#  'C143': 0,
#  'C144': 0,
#  'C145': 0,
#  'C146': 0,
#  'C147': 0,
#  'C148': 0,
#  'C149': 0,
#  'C150': 0,
#  'C151': 0,
#  'C152': 0,
#  'C153': 0,
#  'C154': 0,
#  'C155': 0,
#  'C156': 0,
#  'C157': 0,
#  'C158': 0,
#  'C159': 0,
#  'C160': 0,
#  'C161': 0,
#  'C162': 0,
#  'C163': 0,
#  'C164': 0,
#  'C165': 0,
#  'C166': 0,
#  'C167': 0,
#  'C168': 0,
#  'C169': 0,
#  'C171': 0,
#  'C172': 0,
#  'C173': 0,
#  'C174': 0,
#  'C175': 0,
#  'C176': 0,
#  'C177': 0,
#  'C179': 0,
#  'C180': 0,
#  'C181': 0,
#  'C182': 0,
#  'C183': 0,
#  'C184': 0,
#  'C185': 0,
#  'C186': 0,
#  'C187': 0,
#  'C188': 0,
#  'C189': 0,
#  'C190': 0,
#  'C192': 0,
#  'C194': 0,
#  'C195': 0,
#  'C196': 0,
#  'C197': 0,
#  'C198': 0,
#  'C200': 0,
#  'C201': 0,
#  'C202': 0,
#  'C203': 0,
#  'C204': 0,
#  'C205': 0,
#  'C206': 0,
#  'C207': 0,
#  'C208': 0,
#  'C209': 0,
#  'C210': 0,
#  'C211': 0,
#  'C212': 0,
#  'C214': 0,
#  'C215': 0,
#  'C216': 0,
#  'C217': 0,
#  'C218': 0,
#  'C219': 0,
#  'C220': 0,
#  'C221': 0,
#  'C222': 0,
#  'C223': 0,
#  'C224': 0,
#  'C225': 0,
#  'C226': 0,
#  'C227': 0,
#  'C228': 0,
#  'C229': 0,
#  'C230': 0,
#  'C231': 0,
#  'C232': 0,
#  'C233': 0,
#  'C234': 0,
#  'C235': 0,
#  'C236': 0,
#  'C238': 0,
#  'C239': 0,
#  'C240': 0,
#  'C241': 0,
#  'C242': 0,
#  'C243': 0,
#  'C244': 0,
#  'C245': 0,
#  'C246': 0,
#  'C247': 0,
#  'C248': 0,
#  'C249': 0,
#  'C251': 0,
#  'C252': 0,
#  'C253': 0,
#  'C254': 0,
#  'C255': 0,
#  'C256': 0,
#  'C257': 0,
#  'C259': 0,
#  'C260': 0,
#  'C262': 0,
#  'C263': 0,
#  'C264': 0,
#  'C265': 0,
#  'C266': 0,
#  'C267': 0,
#  'C268': 0,
#  'C269': 0,
#  'C270': 0,
#  'C271': 0,
#  'C272': 0,
#  'C273': 0,
#  'C274': 0,
#  'C276': 0,
#  'C277': 0,
#  'C278': 0,
#  'C279': 0,
#  'C280': 0,
#  'C281': 0,
#  'C282': 0,
#  'C283': 0,
#  'C284': 0,
#  'C285': 0,
#  'C286': 0,
#  'C287': 0,
#  'C288': 0,
#  'C289': 0,
#  'C290': 0,
#  'C291': 0,
#  'C292': 0,
#  'C294': 0,
#  'C295': 0,
#  'C296': 0,
#  'C297': 0,
#  'C298': 0,
#  'C299': 0,
#  'C300': 0,
#  'C301': 0,
#  'C302': 0,
#  'C303': 0,
#  'C304': 0,
#  'C305': 0,
#  'C306': 0,
#  'C307': 0,
#  'C308': 0,
#  'C309': 0,
#  'C310': 0,
#  'C311': 0,
#  'C312': 0,
#  'C313': 0,
#  'C314': 0,
#  'C315': 0,
#  'C316': 0,
#  'C317': 0,
#  'C318': 0,
#  'C320': 0,
#  'C321': 0,
#  'C322': 0,
#  'C323': 0,
#  'C325': 0,
#  'C326': 0,
#  'C327': 0,
#  'C328': 0,
#  'C330': 0,
#  'C331': 0,
#  'C332': 0,
#  'C333': 0,
#  'C334': 0,
#  'C335': 0,
#  'C336': 0,
#  'C337': 0,
#  'C338': 0,
#  'C339': 0,
#  'C340': 0,
#  'C341': 0,
#  'C342': 0,
#  'C345': 0,
#  'C346': 0,
#  'C347': 0,
#  'C348': 0,
#  'C349': 0,
#  'C350': 0,
#  'C352': 0,
#  'C353': 0,
#  'C354': 0,
#  'C355': 0,
#  'C356': 0,
#  'C357': 0,
#  'C360': 0,
#  'C361': 0,
#  'C362': 0,
#  'C363': 0,
#  'C364': 0,
#  'C365': 0,
#  'C366': 0,
#  'C367': 0,
#  'C368': 0,
#  'C369': 0,
#  'C370': 0,
#  'C372': 0,
#  'C373': 0,
#  'C374': 0,
#  'C375': 0,
#  'C376': 0,
#  'C377': 0,
#  'C378': 0,
#  'C379': 0,
#  'C380': 0,
#  'C381': 0,
#  'C382': 0,
#  'C383': 0,
#  'C384': 0,
#  'D2149': 1,
#  'D2910': 1,
#  'D3684': 1,
#  'D3754': 1,
#  'D766': 1,
#  'D1854': 1,
#  'D2166': 1,
#  'D88': 1,
#  'D2242': 1,
#  'D2637': 1,
#  'D2745': 1,
#  'D3862': 1,
#  'D639': 1,
#  'D2606': 1,
#  'D4391': 1,
#  'D207': 1,
#  'D1290': 1,
#  'D1576': 1,
#  'D3153': 1,
#  'D744': 1,
#  'D3558': 1,
#  'D313': 1,
#  'D409': 1,
#  'D1640': 1,
#  'D2814': 1,
#  'D4285': 1,
#  'D5342': 1,
#  'D5436': 1,
#  'D1011': 1,
#  'D1605': 1,
#  'D4204': 1,
#  'D4870': 1,
#  'D64': 1,
#  'D1286': 1,
#  'D1988': 1,
#  'D3734': 1,
#  'D4124': 1,
#  'D4460': 1,
#  'D937': 1,
#  'D905': 1,
#  'D1236': 1,
#  'D3583': 1,
#  'D4414': 1,
#  'D5467': 1,
#  'D1222': 1,
#  'D1496': 1,
#  'D2171': 1,
#  'D2732': 1,
#  'D3600': 1,
#  'D4345': 1,
#  'D4531': 1,
#  'D5237': 1,
#  'D5539': 1,
#  'D253': 1,
#  'D1021': 1,
#  'D1473': 1,
#  'D3054': 1,
#  'D3219': 1,
#  'D1577': 1,
#  'D5569': 1,
#  'D767': 1,
#  'D2105': 1,
#  'D5441': 1,
#  'D5716': 1,
#  'D361': 1,
#  'D1085': 1,
#  'D3212': 1,
#  'D742': 1,
#  'D3228': 1,
#  'D624': 1,
#  'D2033': 1,
#  'D2826': 1,
#  'D3503': 1,
#  'D3596': 1,
#  'D5447': 1,
#  'D1246': 1,
#  'D1515': 1,
#  'D5169': 1,
#  'D75': 1,
#  'D541': 1,
#  'D2341': 1,
#  'D3563': 1,
#  'D5485': 1,
#  'D642': 1,
#  'D1452': 1,
#  'D2658': 1,
#  'D3409': 1,
#  'D3648': 1,
#  'D5558': 1,
#  'D219': 1,
#  'D2182': 1,
#  'D4194': 1,
#  'D4404': 1,
#  'D4725': 1,
#  'D940': 1,
#  'D1531': 1,
#  'D4277': 1,
#  'D5015': 1,
#  'D775': 1,
#  'D1670': 1,
#  'D3725': 1,
#  'D73': 1,
#  'D204': 1,
#  'D1572': 1,
#  'D5272': 1,
#  'D170': 1,
#  'D425': 1,
#  'D1186': 1,
#  'D1525': 1,
#  'D2958': 1,
#  'D3438': 1,
#  'D3773': 1,
#  'D891': 1,
#  'D3609': 1,
#  'D5528': 1,
#  'D2144': 1,
#  'D2268': 1,
#  'D2636': 1,
#  'D2796': 1,
#  'D2812': 1,
#  'D2840': 1,
#  'D4284': 1,
#  'D4880': 1,
#  'D1059': 1,
#  'D1243': 1,
#  'D1316': 1,
#  'D3094': 1,
#  'D3119': 1,
#  'D687': 1,
#  'D3107': 1,
#  'D3275': 1,
#  'D709': 1,
#  'D833': 1,
#  'D2228': 1,
#  'D276': 1,
#  'D1054': 1,
#  'D3346': 1,
#  'D1123': 1,
#  'D3373': 1,
#  'D5195': 1,
#  'D657': 1,
#  'D2623': 1,
#  'D3708': 1,
#  'D5215': 1,
#  'D358': 1,
#  'D577': 1,
#  'D623': 1,
#  'D684': 1,
#  'D832': 1,
#  'D4892': 1,
#  'D5671': 1,
#  'D718': 1,
#  'D2117': 1,
#  'D2281': 1,
#  'D3245': 1,
#  'D3950': 1,
#  'D4249': 1,
#  'D4961': 1,
#  'D1357': 1,
#  'D2051': 1,
#  'D3033': 1,
#  'D3611': 1,
#  'D3621': 1,
#  'D3852': 1,
#  'D4186': 1,
#  'D1015': 1,
#  'D1686': 1,
#  'D2699': 1,
#  'D2260': 1,
#  'D2823': 1,
#  'D2898': 1,
#  'D2919': 1,
#  'D3222': 1,
#  'D3358': 1,
#  'D2180': 1,
#  'D3244': 1,
#  'D3843': 1,
#  'D4756': 1,
#  'D5100': 1,
#  'D2073': 1,
#  'D2097': 1,
#  'D2158': 1,
#  'D2200': 1,
#  'D4020': 1,
#  'D1538': 1,
#  'D1612': 1,
#  'D1233': 1,
#  'D2176': 1,
#  'D2854': 1,
#  'D4664': 1,
#  'D1997': 1,
#  'D2668': 1,
#  'D3242': 1,
#  'D3317': 1,
#  'D5347': 1,
#  'D947': 1,
#  'D1337': 1,
#  'D2709': 1,
#  'D3589': 1,
#  'D5092': 1,
#  'D396': 1,
#  'D1252': 1,
#  'D3198': 1,
#  'D3827': 1,
#  'D1006': 1,
#  'D2120': 1,
#  'D2450': 1,
#  'D3091': 1,
#  'D4806': 1,
#  'D5118': 1,
#  'D224': 1,
#  'D838': 1,
#  'D1241': 1,
#  'D1931': 1,
#  'D3550': 1,
#  'D3800': 1,
#  'D4021': 1,
#  'D4708': 1,
#  'D1380': 1,
#  'D1770': 1,
#  'D2266': 1,
#  'D3093': 1,
#  'D5020': 1,
#  'D184': 1,
#  'D340': 1,
#  'D3005': 1,
#  'D5321': 1,
#  'D519': 1,
#  'D1707': 1,
#  'D847': 1,
#  'D1119': 1,
#  'D1234': 1,
#  'D1755': 1,
#  'D4357': 1,
#  'D1273': 1,
#  'D1481': 1,
#  'D1930': 1,
#  'D1963': 1,
#  'D2066': 1,
#  'D3230': 1,
#  'D4956': 1,
#  'D5376': 1,
#  'D5449': 1,
#  'D141': 1,
#  'D182': 1,
#  'D916': 1,
#  'D2004': 1,
#  'D4265': 1,
#  'D5227': 1,
#  'D661': 1,
#  'D1717': 1,
#  'D2331': 1,
#  'D3499': 1,
#  'D3587': 1,
#  'D5128': 1,
#  'D968': 1,
#  'D1683': 1,
#  'D2012': 1,
#  'D3783': 1,
#  'D4515': 1,
#  'D16': 1,
#  'D1702': 1,
#  'D2235': 1,
#  'D4503': 1,
#  'D3269': 1,
#  'D4458': 1,
#  'D5420': 1,
#  'D1414': 1,
#  'D1432': 1,
#  'D1996': 1,
#  'D2016': 1,
#  'D1208': 1,
#  'D3813': 1,
#  'D5339': 1,
#  'D3432': 1,
#  'D3872': 1,
#  'D4823': 1,
#  'D5160': 1,
#  'D1045': 1,
#  'D1535': 1,
#  'D1709': 1,
#  'D3189': 1,
#  'D4302': 1,
#  'D3': 1,
#  'D545': 1,
#  'D4041': 1,
#  'D4822': 1,
#  'D5488': 1,
#  'D1520': 1,
#  'D3553': 1,
#  'D5006': 1,
#  'D1305': 1,
#  'D2676': 1,
#  'D5134': 1,
#  'D5203': 1,
#  'D96': 1,
#  'D1631': 1,
#  'D3863': 1,
#  'D42': 1,
#  'D146': 1,
#  'D1633': 1,
#  'D4455': 1,
#  'D4548': 1,
#  'D877': 1,
#  'D1302': 1,
#  'D4089': 1,
#  'D472': 1,
#  'D562': 1,
#  'D2090': 1,
#  'D2385': 1,
#  'D4510': 1,
#  'D622': 1,
#  'D3910': 1,
#  'D3969': 1,
#  'D1078': 1,
#  'D1428': 1,
#  'D104': 1,
#  'D277': 1,
#  'D888': 1,
#  'D1132': 1,
#  'D1630': 1,
#  'D1008': 1,
#  'D2631': 1,
#  'D4681': 1,
#  'D5456': 1,
#  'D1270': 1,
#  'D2447': 1,
#  'D3799': 1,
#  'D571': 1,
#  'D3199': 1,
#  'D3610': 1,
#  'D5225': 1,
#  'D41': 1,
#  'D797': 1,
#  'D4072': 1,
#  'D2430': 1,
#  'D4937': 1,
#  'D5243': 1,
#  'D49': 1,
#  'D2622': 1,
#  'D3730': 1,
#  'D4995': 1,
#  'D587': 1,
#  'D1350': 1,
#  'D2036': 1,
#  'D2858': 1,
#  'D4059': 1,
#  'D1589': 1,
#  'D2197': 1,
#  'D4690': 1,
#  'D2305': 1,
#  'D3246': 1,
#  'D3777': 1,
#  'D4152': 1,
#  'D4462': 1,
#  'D4721': 1,
#  'D4736': 1,
#  'D682': 1,
#  'D1636': 1,
#  'D2131': 1,
#  'D3283': 1,
#  'D3616': 1,
#  'D1982': 1,
#  'D2963': 1,
#  'D3032': 1,
#  'D4113': 1,
#  'D5070': 1,
#  'D1793': 1,
#  'D2126': 1,
#  'D5304': 1,
#  'D5641': 1,
#  'D2955': 1,
#  'D4436': 1,
#  'D4861': 1,
#  'D5204': 1,
#  'D5493': 1,
#  'D211': 1,
#  'D593': 1,
#  'D602': 1,
#  'D810': 1,
#  'D1734': 1,
#  'D5460': 1,
#  'D640': 1,
#  'D2511': 1,
#  'D2833': 1,
#  'D5498': 1,
#  'D48': 1,
#  'D196': 1,
#  'D1334': 1,
#  'D2444': 1,
#  'D2957': 1,
#  'D3072': 1,
#  'D427': 1,
#  'D3305': 1,
#  'D665': 1,
#  'D3658': 1,
#  'D4735': 1,
#  'D855': 1,
#  'D5712': 1,
#  'D2141': 1,
#  'D2420': 1,
#  'D3804': 1,
#  'D226': 1,
#  'D2020': 1,
#  'D2664': 1,
#  'D4727': 1,
#  'D1744': 1,
#  'D2240': 1,
#  'D3167': 1,
#  'D3825': 1,
#  'D3901': 1,
#  'D985': 1,
#  'D1177': 1,
#  'D4923': 1,
#  'D11': 1,
#  'D81': 1,
#  'D191': 1,
#  'D434': 1,
#  'D1064': 1,
#  'D2148': 1,
#  'D831': 1,
#  'D2334': 1,
#  'D3037': 1,
#  'D3185': 1,
#  'D3286': 1,
#  'D3795': 1,
#  'D569': 1,
#  'D2395': 1,
#  'D2747': 1,
#  'D5542': 1,
#  'D771': 1,
#  'D895': 1,
#  'D459': 1,
#  'D506': 1,
#  'D4412': 1,
#  'D1713': 1,
#  'D3095': 1,
#  'D3952': 1,
#  'D4065': 1,
#  'D4947': 1,
#  'D826': 1,
#  'D977': 1,
#  'D1618': 1,
#  'D3614': 1,
#  'D3769': 1,
#  'D5343': 1,
#  'D5368': 1,
#  'D707': 1,
#  'D2533': 1,
#  'D91': 1,
#  'D238': 1,
#  'D679': 1,
#  'D1111': 1,
#  'D5732': 1,
#  'D53': 1,
#  'D2191': 1,
#  'D2566': 1,
#  'D4821': 1,
#  'D5766': 1,
#  'D1550': 1,
#  'D2157': 1,
#  'D2722': 1,
#  'D4354': 1,
#  'D5653': 1,
#  'D217': 1,
#  'D2462': 1,
#  'D3238': 1,
#  'D5064': 1,
#  'D504': 1,
#  'D702': 1,
#  'D761': 1,
#  'D1704': 1,
#  'D2505': 1,
#  'D4367': 1,
#  'D5109': 1,
#  'D151': 1,
#  'D3780': 1,
#  'D3860': 1,
#  'D3878': 1,
#  'D1807': 1,
#  'D2683': 1,
#  'D5233': 1,
#  'D5529': 1,
#  'D946': 1,
#  'D1219': 1,
#  'D1278': 1,
#  'D1980': 1,
#  'D743': 1,
#  'D961': 1,
#  'D4405': 1,
#  'D4963': 1,
#  'D5216': 1,
#  'D666': 1,
#  'D1582': 1,
#  'D2497': 1,
#  'D2805': 1,
#  'D2571': 1,
#  'D4217': 1,
#  'D4848': 1,
#  'D404': 1,
#  'D962': 1,
#  'D2239': 1,
#  'D2926': 1,
#  'D4521': 1,
#  'D3507': 1,
#  'D5557': 1,
#  'D926': 1,
#  'D930': 1,
#  'D1115': 1,
#  'D4190': 1,
#  'D5025': 1,
#  'D588': 1,
#  'D863': 1,
#  'D3055': 1,
#  'D3465': 1,
#  'D4035': 1,
#  'D4252': 1,
#  'D4273': 1,
#  'D4849': 1,
#  'D4868': 1,
#  'D20': 1,
#  'D941': 1,
#  'D2458': 1,
#  'D4024': 1,
#  'D4939': 1,
#  'D4377': 1,
#  'D1559': 1,
#  'D2109': 1,
#  'D2911': 1,
#  'D2948': 1,
#  'D3839': 1,
#  'D4211': 1,
#  'D5754': 1,
#  'D1136': 1,
#  'D1747': 1,
#  'D2820': 1,
#  'D939': 1,
#  'D2380': 1,
#  'D4253': 1,
#  'D5613': 1,
#  'D815': 1,
#  'D2280': 1,
#  'D3608': 1,
#  'D4355': 1,
#  'D730': 1,
#  'D2686': 1,
#  'D728': 1,
#  'D3243': 1,
#  'D5133': 1,
#  'D5474': 1,
#  'D975': 1,
#  'D2128': 1,
#  'D258': 1,
#  'D3426': 1,
#  'D4946': 1,
#  'D5027': 1,
#  'D174': 1,
#  'D252': 1,
#  'D2908': 1,
#  'D4730': 1,
#  'D4964': 1,
#  'D4965': 1,
#  'D5288': 1,
#  'D5666': 1,
#  'D267': 1,
#  'D690': 1,
#  'D1216': 1,
#  'D3193': 1,
#  'D876': 1,
#  'D3000': 1,
#  'D3001': 1,
#  'D4896': 1,
#  'D5138': 1,
#  'D1566': 1,
#  'D3661': 1,
#  'D83': 1,
#  'D377': 1,
#  'D3494': 1,
#  'D468': 1,
#  'D2238': 1,
#  'D4326': 1,
#  'D5192': 1,
#  'D215': 1,
#  'D1215': 1,
#  'D1279': 1,
#  'D1548': 1,
#  'D4679': 1,
#  'D1761': 1,
#  'D2205': 1,
#  'D4792': 1,
#  'D5560': 1,
#  'D2876': 1,
#  'D2975': 1,
#  'D3703': 1,
#  'D4558': 1,
#  'D670': 1,
#  'D1020': 1,
#  'D1920': 1,
#  'D3206': 1,
#  'D3966': 1,
#  'D4096': 1,
#  'D638': 1,
#  'D2032': 1,
#  'D4652': 1,
#  'D5075': 1,
#  'D5660': 1,
#  'D109': 1,
#  'D2070': 1,
#  'D2498': 1,
#  'D2568': 1,
#  'D4388': 1,
#  'D4597': 1,
#  'D1772': 1,
#  'D3181': 1,
#  'D4707': 1,
#  'D5125': 1,
#  'D362': 1,
#  'D1886': 1,
#  'D2093': 1,
#  'D3371': 1,
#  'D3397': 1,
#  'D4646': 1,
#  'D430': 1,
#  'D632': 1,
#  'D1786': 1,
#  'D4337': 1,
#  'D5616': 1,
#  'D100': 1,
#  'D262': 1,
#  'D2894': 1,
#  'D5168': 1,
#  'D1887': 1,
#  'D3220': 1,
#  'D4409': 1,
#  'D1857': 1,
#  'D1995': 1,
#  'D2582': 1,
#  'D2720': 1,
#  'D3850': 1,
#  'D785': 1,
#  'D2903': 1,
#  'D5286': 1,
#  'D984': 1,
#  'D1094': 1,
#  'D2270': 1,
#  ...}

# %% [markdown]
# ## Basic metrics

# %%
# is the graph connected?
nx.is_connected(interlocks_G)
# Out:
# False

# %%
# let's extract largest component
interlocks_gG = sorted(nx.connected_components(interlocks_G), key=len, reverse=True)
interlocks_gG0 = interlocks_G.subgraph(interlocks_gG[0])
print((interlocks_gG0))
# Out:
# Graph with 1066 nodes and 1148 edges

# %%
# For the following metrics, it is helpful to define two groups of nodes
company_nodes = {n for n, d in interlocks_G.nodes(data=True) if d["bipartite"] == 0} # these are the companies
director_nodes = set(interlocks_G) - company_nodes # directors

# %%
# Density (we now go back to the full graph)

# we can calculate it by hand: nb. edges / (company_nodes * director_nodes)
len(interlocks_G.edges())/(len(company_nodes)*len(director_nodes))
# Out:
# 0.0034611610549999503

# %%
# there is also a pre-defined function for bipartite density
nx.bipartite.density(interlocks_G, company_nodes)
# it requires specifying name of graph and one of the two node groups
# Out:
# 0.0034611610549999503

# %%
# Low level of density is partly due to presence of isolates
# Let's compute it now on the largest component only
D4222', 1), ('D2726', 1), ('D2494', 1), ('D545', 1), ('D2646', 1), ('D4441', 1), ('D1887', 1), ('D1081', 1), ('D413', 1), ('D1058', 1), ('D5441', 1), ('D1297', 1), ('D4012', 1), ('D5539', 1), ('D5342', 6), ('D656', 1), ('D4781', 1), ('D559', 1), ('D941', 1), ('D4880', 1), ('D2032', 2), ('D4089', 2), ('D3627', 1), ('D5507', 1), ('D5557', 2), ('D2920', 1), ('D4190', 1), ('D4024', 1), ('D3472', 1), ('D184', 1), ('D2511', 1), ('D5740', 1), ('D4377', 1), ('D5316', 1), ('D826', 1), ('D831', 1), ('D3185', 1), ('D1357', 5), ('D3707', 1), ('D3509', 1), ('D5443', 1), ('D1878', 1), ('D5716', 2), ('D1479', 1), ('D895', 2), ('D635', 1), ('D1577', 1), ('D2721', 1), ('D2534', 1), ('D4610', 1), ('D2358', 1), ('D3414', 1), ('D4455', 1), ('D3220', 1), ('D216', 2), ('D3548', 1), (' ...

# %%
# Clustering coefficient, CC (local)
nx.bipartite.clustering(interlocks_G, company_nodes, mode='dot') 
# same as regular CC but considers second-order neighbors
# Out:
# {'C88': 1.0,
#  'C8': 0.1714285714285714,
#  'C210': 0.0,
#  'C222': 0.11871263656977941,
#  'C57': 0.07269345238095237,
#  'C331': 0.05601851851851852,
#  'C174': 0.0,
#  'C305': 0.23214285714285718,
#  'C29': 0.0,
#  'C11': 0.08841491841491841,
#  'C106': 0.1,
#  'C302': 0.14583333333333331,
#  'C227': 0.0857142857142857,
#  'C13': 0.14285714285714285,
#  'C336': 0.2,
#  'C108': 0.09074074074074073,
#  'C40': 0.0,
#  'C126': 0.17671957671957672,
#  'C42': 0.14285714285714285,
#  'C101': 0.12316239316239316,
#  'C73': 0.10690235690235689,
#  'C368': 0.08927738927738928,
#  'C96': 0.10555555555555556,
#  'C172': 0.125,
#  'C85': 0.09090909090909091,
#  'C241': 0.09601139601139601,
#  'C353': 0.1,
#  'C39': 0.1372377622377622,
#  'C63': 0.12698412698412698,
#  'C365': 0.09090909090909091,
#  'C252': 0.20000000000000004,
#  'C379': 0.09166666666666667,
#  'C259': 0.0886243386243386,
#  'C326': 0.2,
#  'C356': 0.0625,
#  'C167': 0.1,
#  'C26': 0.0,
#  'C78': 0.0,
#  'C198': 0.1111111111111111,
#  'C282': 0.75,
#  'C283': 0.0,
#  'C93': 0.09814814814814815,
#  'C132': 0.18560606060606064,
#  'C134': 0.0,
#  'C4': 0.16444444444444445,
#  'C273': 0.12451499118165785,
#  'C48': 0.10606060606060606,
#  'C151': 0.1074074074074074,
#  'C100': 0.1111111111111111,
#  'C279': 0.08347902097902098,
#  'C138': 0.0,
#  'C307': 0.16161616161616163,
#  'C55': 0.12843915343915344,
#  'C67': 0.11180555555555555,
#  'C248': 0.1,
#  'C56': 0.1074074074074074,
#  'C312': 0.14285714285714285,
#  'C86': 0.1111111111111111,
#  'C309': 0.0,
#  'C47': 0.0,
#  'C231': 0.12976190476190474,
#  'C232': 0.30456349206349204,
#  'C18': 0.0,
#  'C142': 0.1111111111111111,
#  'C187': 0.1111111111111111,
#  'C17': 0.10303030303030303,
#  'C229': 0.14285714285714285,
#  'C22': 0.10722222222222222,
#  'C25': 0.10873015873015873,
#  'C342': 0.0,
#  'C159': 0.0,
#  'C5': 0.10437710437710439,
#  'C99': 0.17523809523809525,
#  'C325': 0.0625,
#  'C311': 0.14285714285714285,
#  'C354': 0.1,
#  'C228': 0.1388888888888889,
#  'C220': 0.07142857142857142,
#  'C144': 0.13333333333333333,
#  'C89': 0.09356384356384356,
#  'C267': 0.10606060606060606,
#  'C103': 0.12698412698412698,
#  'C107': 0.0,
#  'C316': 0.0,
#  'C118': 0.125,
#  'C75': 1.0,
#  'C341': 0.0,
#  'C27': 0.10867003367003368,
#  'C181': 0.12169312169312169,
#  'C31': 0.07142857142857142,
#  'C214': 0.0,
#  'C36': 0.11626984126984127,
#  'C185': 0.0,
#  'C308': 0.0,
#  'C207': 0.0,
#  'C133': 0.17152777777777778,
#  'C265': 0.14285714285714285,
#  'C240': 0.0,
#  'C37': 0.09166666666666667,
#  'C300': 0.12152777777777778,
#  'C129': 0.1874747474747475,
#  'C366': 0.08712121212121213,
#  'C370': 0.09913419913419913,
#  'C79': 0.07738095238095238,
#  'C196': 0.2857142857142857,
#  'C320': 0.0,
#  'C117': 0.09126984126984126,
#  'C158': 0.0,
#  'C120': 0.0,
#  'C122': 0.1125,
#  'C161': 0.10937950937950938,
#  'C203': 0.6,
#  'C357': 0.13333333333333333,
#  'C286': 0.10174825174825175,
#  'C12': 0.27142857142857146,
#  'C277': 0.1292768959435626,
#  'C41': 0.08333333333333333,
#  'C204': 0.6,
#  'C83': 0.125,
#  'C272': 0.08641774891774891,
#  'C315': 0.0,
#  'C128': 0.0,
#  'C303': 0.19642857142857142,
#  'C110': 0.125,
#  'C53': 0.09090909090909091,
#  'C136': 0.396969696969697,
#  'C327': 0.2,
#  'C217': 0.11626984126984126,
#  'C152': 0.0846153846153846,
#  'C90': 0.0,
#  'C168': 0.1087742504409171,
#  'C382': 0.0,
#  'C156': 0.0,
#  'C251': 0.1111111111111111,
#  'C338': 0.15555555555555556,
#  'C287': 0.0,
#  'C111': 0.08333333333333333,
#  'C71': 0.14464285714285713,
#  'C225': 0.08617810760667903,
#  'C205': 0.0,
#  'C247': 0.23946886446886448,
#  'C16': 0.14761904761904762,
#  'C61': 0.125,
#  'C76': 0.09894179894179894,
#  'C233': 0.2,
#  'C299': 0.10795454545454546,
#  'C160': 0.1,
#  'C195': 0.0,
#  'C147': 0.14285714285714285,
#  'C288': 0.09764309764309764,
#  'C188': 0.08333333333333333,
#  'C177': 0.09292929292929293,
#  'C6': 0.14285714285714285,
#  'C328': 0.11495911495911497,
#  'C221': 0.1111111111111111,
#  'C244': 0.06857142857142857,
#  'C30': 0.07722832722832723,
#  'C49': 0.11686507936507935,
#  'C2': 0.0,
#  'C97': 0.14285714285714285,
#  'C298': 0.08846153846153847,
#  'C223': 0.08712121212121211,
#  'C153': 0.09090909090909091,
#  'C91': 0.09632034632034632,
#  'C254': 0.275,
#  'C219': 0.0,
#  'C276': 0.18333333333333335,
#  'C362': 0.29166666666666663,
#  'C372': 0.09090909090909091,
#  'C360': 0.0,
#  'C44': 0.3666666666666667,
#  'C337': 0.15132275132275133,
#  'C290': 0.0,
#  'C376': 0.0,
#  'C7': 0.13714285714285712,
#  'C77': 0.0,
#  'C173': 0.0,
#  'C165': 0.0,
#  'C304': 0.21263227513227512,
#  'C119': 0.08333333333333333,
#  'C87': 1.0,
#  'C264': 0.06593978937728938,
#  'C66': 0.0,
#  'C145': 0.0,
#  'C330': 0.0,
#  'C52': 0.08158508158508158,
#  'C192': 0.07692307692307693,
#  'C238': 0.0,
#  'C294': 0.1111111111111111,
#  'C257': 0.1111111111111111,
#  'C154': 0.09090909090909091,
#  'C33': 0.14285714285714285,
#  'C310': 0.0,
#  'C262': 0.0868997668997669,
#  'C206': 0.0,
#  'C184': 0.1111111111111111,
#  'C70': 0.1625,
#  'C364': 0.0,
#  'C202': 0.0,
#  'C163': 0.14285714285714285,
#  'C135': 0.0,
#  'C45': 0.0,
#  'C246': 0.2512987012987013,
#  'C182': 0.0,
#  'C189': 0.09511784511784512,
#  'C23': 0.08658008658008658,
#  'C186': 0.07722832722832723,
#  'C255': 0.2,
#  'C1': 0.0,
#  'C139': 0.1314625850340136,
#  'C58': 0.396969696969697,
#  'C270': 0.0,
#  'C60': 0.0,
#  'C335': 0.0,
#  'C24': 0.10795454545454546,
#  'C115': 0.0,
#  'C313': 0.0,
#  'C375': 0.07692307692307693,
#  'C155': 0.09583333333333333,
#  'C169': 0.75,
#  'C263': 0.14285714285714285,
#  'C3': 0.14301587301587304,
#  'C297': 0.06666666666666667,
#  'C256': 0.27499999999999997,
#  'C340': 0.23214285714285712,
#  'C347': 0.0,
#  'C121': 0.125,
#  'C284': 0.10666666666666665,
#  'C15': 0.1031866281866282,
#  'C104': 0.09814814814814815,
#  'C43': 0.12316239316239316,
#  'C269': 0.0,
#  'C94': 0.0,
#  'C236': 0.12023809523809523,
#  'C242': 0.0,
#  'C197': 0.09555555555555555,
#  'C14': 0.06904761904761905,
#  'C306': 0.0,
#  'C201': 0.0,
#  'C314': 0.0,
#  'C318': 0.0,
#  'C148': 0.10555555555555556,
#  'C374': 0.09166666666666667,
#  'C130': 0.13398268398268398,
#  'C218': 0.0,
#  'C245': 0.0,
#  'C373': 1.0,
#  'C194': 0.0,
#  'C381': 0.0,
#  'C35': 0.14285714285714285,
#  'C105': 0.0,
#  'C64': 0.0,
#  'C141': 0.17523809523809525,
#  'C333': 0.07945804195804196,
#  'C171': 0.12649911816578482,
#  'C190': 0.0,
#  'C150': 0.09625136767993912,
#  'C164': 0.11495510662177327,
#  'C378': 0.0,
#  'C291': 0.0,
#  'C143': 0.08712121212121213,
#  'C146': 0.13826530612244897,
#  'C127': 0.0,
#  'C74': 1.0,
#  'C113': 0.1009939134939135,
#  'C361': 0.09141414141414143,
#  'C321': 0.0,
#  'C157': 0.10238095238095236,
#  'C92': 0.1364389578675293,
#  'C38': 0.09516705516705518,
#  'C125': 0.0,
#  'C166': 0.30456349206349204,
#  'C350': 0.0,
#  'C355': 0.0,
#  'C243': 0.0,
#  'C212': 0.0,
#  'C54': 0.0,
#  'C226': 0.1,
#  'C10': 0.23611111111111108,
#  'C149': 0.1111111111111111,
#  'C112': 0.0735042735042735,
#  'C280': 0.0,
#  'C211': 0.0,
#  'C334': 0.10101010101010101,
#  'C84': 0.0,
#  'C281': 0.1082070707070707,
#  'C28': 0.09090909090909091,
#  'C274': 0.16072631072631074,
#  'C235': 0.0,
#  'C109': 0.10548441457532366,
#  'C234': 0.2,
#  'C140': 0.10375180375180375,
#  'C19': 0.1625,
#  'C175': 0.0888888888888889,
#  'C266': 1.0,
#  'C295': 0.10000000000000002,
#  'C268': 0.09166666666666667,
#  'C65': 0.0,
#  'C209': 0.0,
#  'C348': 0.07514880952380952,
#  'C332': 0.0,
#  'C239': 0.0,
#  'C285': 0.10908011741345074,
#  'C289': 0.0,
#  'C301': 0.16623376623376623,
#  'C377': 0.09090909090909091,
#  'C59': 0.08333333333333333,
#  'C349': 0.12698412698412698,
#  'C183': 0.10252525252525253,
#  'C81': 0.0,
#  'C32': 0.14285714285714285,
#  'C62': 0.0,
#  'C253': 0.20000000000000004,
#  'C200': 0.09696969696969697,
#  'C230': 0.10277777777777777,
#  'C180': 0.0,
#  'C249': 0.0,
#  'C20': 0.13735708735708735,
#  'C215': 0.0,
#  'C363': 0.1,
#  'C384': 0.1111111111111111,
#  'C162': 0.11269841269841269,
#  'C322': 0.11405895691609978,
#  'C383': 0.09814814814814815,
#  'C179': 0.12945804195804198,
#  'C137': 0.1111111111111111,
#  'C34': 0.1111111111111111,
#  'C271': 0.08838383838383838,
#  'C317': 0.09166666666666667,
#  'C98': 0.0,
#  'C72': 0.0,
#  'C102': 0.14285714285714285,
#  'C352': 0.0,
#  'C80': 0.0,
#  'C367': 0.0,
#  'C51': 0.08333333333333333,
#  'C216': 0.0,
#  'C339': 0.0,
#  'C296': 0.09525252525252527,
#  'C380': 0.2222222222222222,
#  'C208': 0.0,
#  'C21': 0.13640873015873015,
#  'C82': 0.1106060606060606,
#  'C176': 0.11146785313451983,
#  'C278': 0.20535714285714285,
#  'C131': 0.13333333333333333,
#  'C292': 0.11805555555555555,
#  'C345': 0.0,
#  'C346': 0.0,
#  'C369': 0.0,
#  'C224': 0.15067340067340065,
#  'C95': 0.1,
#  'C114': 0.0787878787878788,
#  'C260': 0.11495911495911497,
#  'C323': 0.0}

# %%
# Average of local CC
nx.bipartite.average_clustering(interlocks_G, nodes=company_nodes, mode='dot')
# calculation as above
# Out:
# 0.10920942816394318

# %% [markdown]
# ## Projections

# %%
# first the graph of companies
company_graph = nx.bipartite.projection.projected_graph(interlocks_G, company_nodes) # does not take into account weights
print((company_graph))
# Out:
# Graph with 355 nodes and 421 edges

# %%
# Let's look at the edges
company_graph.edges(data=True)
# Out:
C109': 11, 'C234': 1, 'C140': 7, 'C19': 2, 'C175': 3, 'C266': 1, 'C295': 3, 'C268': 2, 'C65': 0, 'C209': 0, 'C348': 4, 'C332': 0, 'C239': 0, 'C285': 9, 'C289': 0, 'C301': 11, 'C377': 1, 'C59': 3, 'C349': 2, 'C183': 6, 'C81': 0, 'C32': 1, 'C62': 0, 'C253': 3, 'C200': 3, 'C230': 4, 'C180': 0, 'C249': 0, 'C20': 8, 'C215': 0, 'C363': 1, 'C384': 1, 'C162': 8, 'C322': 7, 'C383': 3, 'C179': 4, 'C137': 1, 'C34': 1, 'C271': 3, 'C317': 2, 'C98': 0, 'C72': 0, 'C102': 1, 'C352': 0, 'C80': 0, 'C367': 0, 'C51': 1, 'C216': 0, 'C339': 0, 'C296': 5, 'C380': 1, 'C208': 0, 'C21': 4, 'C82': 7, 'C176': 9, 'C278': 2, 'C131': 1, 'C292': 2, 'C345': 0, 'C346': 0, 'C369': 0, 'C224': 3, 'C95': 1, 'C114': 2, 'C260': 3, 'C323': 0})

# %%
# to build a company graph that takes weights into account:
company_graph_2 = nx.bipartite.weighted_projected_graph(interlocks_G, company_nodes, ratio=False)
print((company_graph_2))
# Out:
# Graph with 355 nodes and 421 edges

# %%
# Let's look at the edges
company_graph_2.edges(data=True) # this time it takes into account weights
# Out:
# EdgeDataView([('C88', 'C87', {'weight': 3}), ('C8', 'C176', {'weight': 1}), ('C8', 'C7', {'weight': 2}), ('C8', 'C49', {'weight': 1}), ('C8', 'C322', {'weight': 1}), ('C8', 'C36', {'weight': 1}), ('C222', 'C305', {'weight': 1}), ('C222', 'C303', {'weight': 1}), ('C222', 'C277', {'weight': 1}), ('C222', 'C113', {'weight': 1}), ('C222', 'C28', {'weight': 1}), ('C222', 'C304', {'weight': 1}), ('C222', 'C301', {'weight': 1}), ('C57', 'C166', {'weight': 1}), ('C57', 'C157', {'weight': 1}), ('C57', 'C126', {'weight': 1}), ('C57', 'C232', {'weight': 1}), ('C57', 'C109', {'weight': 1}), ('C57', 'C162', {'weight': 1}), ('C57', 'C325', {'weight': 1}), ('C57', 'C31', {'weight': 1}), ('C331', 'C23', {'weight': 1}), ('C331', 'C356', {'weight': 1}), ('C331', 'C264', {'weight': 1}), ('C305', 'C303', {'weight': 2}), ('C305', 'C277', {'weight': 1}), ('C305', 'C304', {'weight': 3}), ('C305', 'C301', {'weight': 1}), ('C305', 'C300', {'weight': 1}), ('C11', 'C328', {'weight': 1}), ('C11', 'C286', {'weight': 1}), ('C11', 'C108', {'weight': 1}), ('C11', 'C85', {'weight': 1}), ('C11', 'C10', {'weight': 1}), ('C106', 'C177', {'weight': 1}), ('C106', 'C241', {'weight': 1}), ('C302', 'C301', {'weight': 1}), ('C302', 'C300', {'weight': 1}), ('C227', 'C101', {'weight': 1}), ('C227', 'C181', {'weight': 2}), ('C227', 'C43', {'weight': 1}), ('C227', 'C144', {'weight': 1}), ('C13', 'C263', {'weight': 1}), ('C336', 'C338', {'weight': 1}), ('C336', 'C337', {'weight': 1}), ('C108', 'C286', {'weight': 1}), ('C108', 'C271', {'weight': 1}), ('C108', 'C38', {'weight': 1}), ('C108', 'C10', {'weight': 1}), ('C108', 'C183', {'weight': 1}), ('C126', 'C166', {'weight': 2}), ('C126', 'C157', {'weight': 1}), ('C126', 'C109', {'weight': 1}), ('C126', 'C162', {'weight': 1}), ('C126', 'C232', {'weight': 2}), ('C42', 'C312', {'weight': 1}), ('C101', 'C52', {'weight': 1}), ('C101', 'C148', {'weight': 1}), ('C101', 'C43', {'weight': 2}), ('C101', 'C181', {'weight': 1}), ('C73', 'C288', {'weight': 1}), ('C73', 'C109', {'weight': 1}), ('C73', 'C140', {'weight': 1}), ('C73', 'C39', {'weight': 2}), ('C73', 'C384', {'weight': 1}), ('C73', 'C274', {'weight': 1}), ('C368', 'C248', {'weight': 1}), ('C368', 'C246', {'weight': 1}), ('C368', 'C247', {'weight': 1}), ('C96', 'C95', {'weight': 1}), ('C96', 'C113', {'weight': 1}), ('C172', 'C70', {'weight': 1}), ('C85', 'C286', {'weight': 1}), ('C241', 'C183', {'weight': 1}), ('C241', 'C112', {'weight': 1}), ('C353', 'C383', {'weight': 1}), ('C39', 'C129', {'weight': 3}), ('C39', 'C130', {'weight': 3}), ('C39', 'C189', {'weight': 1}), ('C39', 'C288', {'weight': 1}), ('C39', 'C150', {'weight': 1}), ('C39', 'C109', {'weight': 1}), ('C39', 'C140', {'weight': 1}), ('C39', 'C177', {'weight': 1}), ('C39', 'C274', {'weight': 1}), ('C63', 'C296', {'weight': 1}), ('C63', 'C97', {'weight': 1}), ('C365', 'C372', {'weight': 1}), ('C252', 'C254', {'weight': 1}), ('C252', 'C253', {'weight': 1}), ('C252', 'C256', {'weight': 1}), ('C379', 'C259', {'weight': 1}), ('C379', 'C274', {'weight': 1}), ('C259', 'C34', {'weight': 1}), ('C259', 'C348', {'weight': 1}), ('C326', 'C327', {'weight': 1}), ('C167', 'C157', {'weight': 1}), ('C198', 'C3', {'weight': 1}), ('C282', 'C169', {'weight': 3}), ('C93', 'C30', {'weight': 1}), ('C93', 'C262', {'weight': 1}), ('C93', 'C236', {'weight': 1}), ('C132', 'C136', {'weight': 1}), ('C132', 'C58', {'weight': 1}), ('C132', 'C133', {'weight': 3}), ('C4', 'C230', {'weight': 1}), ('C4', 'C151', {'weight': 1}), ('C4', 'C5', {'weight': 1}), ('C4', 'C224', {'weight': 2}), ('C4', 'C3', {'weight': 2}), ('C273', 'C89', {'weight': 1}), ('C273', 'C91', {'weight': 1}), ('C273', 'C279', {'weight': 1}), ('C273', 'C139', {'weight': 1}), ('C273', 'C118', {'weight': 1}), ('C273', 'C171', {'weight': 2}), ('C273', 'C168', {'weight': 1}), ('C273', 'C285', {'weight': 1}), ('C273', 'C164', {'weight': 1}), ('C48', 'C307', {'weight': 1}), ('C48', 'C271', {'weight': 1}), ('C48', 'C142', {'weight': 1}), ('C48', 'C144', {'weight': 1}), ('C151', 'C230', {'w ...

# %% [markdown]
# ### Home exercise:
#
# ##### 1: Re-do the same analyses with the file used in class, but using the Directors projection.
#
# ##### 2: Re-do the same analyses done in class (Companies projection), but with data for a different month.
